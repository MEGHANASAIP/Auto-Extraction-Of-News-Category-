# %% [markdown]
# <a href="https://colab.research.google.com/github/MEGHANASAIP/Auto-Extraction-Of-News-Category-/blob/main/Auto_Extraction_Of_News_Category_Using_BOW_N.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-38ebddd4-26b2-4f37-9cb4-faa1d3ffd51e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-38ebddd4-26b2-4f37-9cb4-faa1d3ffd51e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile

with zipfile.ZipFile("/content/archive (2).zip", 'r') as zip_ref:
    zip_ref.extractall("/content/extracted")

# %%
path='/content/extracted/News_Category_Dataset_v3.json'

# %%
df=pd.read_json(path,lines=True)

# %%
df.head()
# Out:
#                                                 link  \
# 0  https://www.huffpost.com/entry/covid-boosters-...
# 1  https://www.huffpost.com/entry/american-airlin...
# 2  https://www.huffpost.com/entry/funniest-tweets...
# 3  https://www.huffpost.com/entry/funniest-parent...
# 4  https://www.huffpost.com/entry/amy-cooper-lose...
#
#                                             headline   category  \
# 0  Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
# 1  American Airlines Flyer Charged, Banned For Li...  U.S. NEWS
# 2  23 Of The Funniest Tweets About Cats And Dogs ...     COMEDY
# 3  The Funniest Tweets From Parents This Week (Se...  PARENTING
# 4  Woman Who Called Cops On Black Bird-Watcher Lo...  U.S. NEWS
#
#                                    short_description               authors  \
# 0  Health experts said it is too early to predict...  Carla K. Johnson, AP
# 1  He was subdued by passengers and crew when he ...        Mary Papenfuss
# ...

# %%
df.category.value_counts()
# Out:
# category
# POLITICS          35602
# WELLNESS          17945
# ENTERTAINMENT     17362
# TRAVEL             9900
# STYLE & BEAUTY     9814
# PARENTING          8791
# HEALTHY LIVING     6694
# QUEER VOICES       6347
# FOOD & DRINK       6340
# BUSINESS           5992
# COMEDY             5400
# SPORTS             5077
# BLACK VOICES       4583
# HOME & LIVING      4320
# PARENTS            3955
# THE WORLDPOST      3664
# WEDDINGS           3653
# WOMEN              3572
# CRIME              3562
# IMPACT             3484
# DIVORCE            3426
# WORLD NEWS         3299
# MEDIA              2944
# WEIRD NEWS         2777
# GREEN              2622
# WORLDPOST          2579
# RELIGION           2577
# STYLE              2254
# SCIENCE            2206
# TECH               2104
# TASTE              2096
# MONEY              1756
# ARTS               1509
# ENVIRONMENT        1444
# FIFTY              1401
# GOOD NEWS          1398
# U.S. NEWS          1377
# ARTS & CULTURE     1339
# ...

# %% [markdown]
# THERE IS AN IMBALANCE IN THE DATASET SO WE HAVE DO SAMPLING
# HERE WE WILL BE DOING UNDER SAMPLING

# %%
min_size=1014
df1=df[df.category=='POLITICS'].sample(min_size,random_state=2025)

# %%
df2=df[df.category=='WELLNESS'].sample(min_size,random_state=2025)
df3=df[df.category=='ENTERTAINMENT'].sample(min_size,random_state=2025)
df4=df[df.category=='TRAVEL'].sample(min_size,random_state=2025)
df5=df[df.category=='STYLE & BEAUTY'].sample(min_size,random_state=2025)
df6=df[df.category=='PARENTING'].sample(min_size,random_state=2025)
df7=df[df.category=='HEALTHY LIVING'].sample(min_size,random_state=2025)
df8=df[df.category=='QUEER VOICES'].sample(min_size,random_state=2025)
df9=df[df.category=='FOOD & DRINK'].sample(min_size,random_state=2025)
df10=df[df.category=='BUSINESS'].sample(min_size,random_state=2025)
df11=df[df.category=='COMEDY'].sample(min_size,random_state=2025)
df12=df[df.category=='SPORTS'].sample(min_size,random_state=2025)
df13=df[df.category=='BLACK VOICES'].sample(min_size,random_state=2025)
df14=df[df.category=='HOME & LIVING'].sample(min_size,random_state=2025)
df15=df[df.category=='PARENTS'].sample(min_size,random_state=2025)
df16=df[df.category=='THE WORLDPOST'].sample(min_size,random_state=2025)
df17=df[df.category=='WEDDINGS'].sample(min_size,random_state=2025)
df18=df[df.category=='WOMEN'].sample(min_size,random_state=2025)
df19=df[df.category=='CRIME'].sample(min_size,random_state=2025)
df20=df[df.category=='IMPACT'].sample(min_size,random_state=2025)
df21=df[df.category=='DIVORCE'].sample(min_size,random_state=2025)
df22=df[df.category=='WORLD NEWS'].sample(min_size,random_state=2025)
df23=df[df.category=='MEDIA'].sample(min_size,random_state=2025)
df24=df[df.category=='WEIRD NEWS'].sample(min_size,random_state=2025)
df25=df[df.category=='GREEN'].sample(min_size,random_state=2025)
df26=df[df.category=='WORLDPOST'].sample(min_size,random_state=2025)
df27=df[df.category=='RELIGION'].sample(min_size,random_state=2025)
df28=df[df.category=='STYLE'].sample(min_size,random_state=2025)
df29=df[df.category=='SCIENCE'].sample(min_size,random_state=2025)
df30=df[df.category=='TECH'].sample(min_size,random_state=2025)
df31=df[df.category=='TASTE'].sample(min_size,random_state=2025)
df32=df[df.category=='MONEY'].sample(min_size,random_state=2025)
df33=df[df.category=='ARTS'].sample(min_size,random_state=2025)
df34=df[df.category=='ENVIRONMENT'].sample(min_size,random_state=2025)
df35=df[df.category=='FIFTY'].sample(min_size,random_state=2025)
df36=df[df.category=='GOOD NEWS'].sample(min_size,random_state=2025)
df37=df[df.category=='U.S. NEWS'].sample(min_size,random_state=2025)
df38=df[df.category=='ARTS & CULTURE'].sample(min_size,random_state=2025)
df39=df[df.category=='COLLEGE'].sample(min_size,random_state=2025)
df40=df[df.category=='LATINO VOICES'].sample(min_size,random_state=2025)
df41=df[df.category=='CULTURE & ARTS'].sample(min_size,random_state=2025)
df42=df[df.category=='EDUCATION'].sample(min_size,random_state=2025)

# %%
df_balanced=pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27,df28,df29,df30,df31,df32,df33,df34],axis=0)

# %%
df_balanced.head()
# Out:
#                                                     link  \
# 81347  https://www.huffingtonpost.com/entry/huffpost-...
# 12402  https://www.huffingtonpost.com/entry/cambridge...
# 86846  https://www.huffingtonpost.com/entry/oregon-gu...
# 42243  https://www.huffingtonpost.com/entry/trump-ind...
# 74491  https://www.huffingtonpost.comhttp://www.msnbc...
#
#                                                 headline  category  \
# 81347  HuffPost Rise: What You Need To Know On Decemb...  POLITICS
# 12402  Cambridge Analytica Execs Bragged Of Using Fak...  POLITICS
# 86846  Even Americans Who Favor Gun Control Aren't Ve...  POLITICS
# 42243  Indiana Workers Beg Governor To Save Their Job...  POLITICS
# 74491  Report: Bernie Didn't Have A Concession Speech...  POLITICS
#
#                                        short_description             authors  \
# 81347  Welcome to the HuffPost Rise Morning Newsbrief...
# 12402  The admissions were recorded during a probe in...      Nina Golgowski
# ...

# %%
df_balanced.reset_index()
# Out:
#         index                                               link  \
# 0       81347  https://www.huffingtonpost.com/entry/huffpost-...
# 1       12402  https://www.huffingtonpost.com/entry/cambridge...
# 2       86846  https://www.huffingtonpost.com/entry/oregon-gu...
# 3       42243  https://www.huffingtonpost.com/entry/trump-ind...
# 4       74491  https://www.huffingtonpost.comhttp://www.msnbc...
# ...       ...                                                ...
# 34471  168440  https://www.huffingtonpost.com/entry/the-hoax_...
# 34472  177689  https://www.huffingtonpost.com/entry/extreme-w...
# 34473  143926  https://www.huffingtonpost.com/entry/orangutan...
# 34474  165650  https://www.huffingtonpost.com/entry/extremely...
# 34475  146497  https://www.huffingtonpost.com/entry/sustainab...
#
#                                                 headline     category  \
# 0      HuffPost Rise: What You Need To Know On Decemb...     POLITICS
# ...

# %%
import spacy

# %%
nlp=spacy.load('en_core_web_sm')

# %%
def preprocess(text):
  doc=nlp(text)
  processed=[]
  for token in doc:
    if not token.is_stop and not token.is_punct:
      processed.append(token.lemma_)
  return " ".join(processed)

# %%
df_balanced['processed_headline']=df_balanced['headline'].apply(preprocess)

# %%
category_dict = {
    'POLITICS': 1,
    'WELLNESS': 2,
    'ENTERTAINMENT': 3,
    'TRAVEL': 4,
    'STYLE & BEAUTY': 5,
    'PARENTING': 6,
    'HEALTHY LIVING': 7,
    'QUEER VOICES': 8,
    'FOOD & DRINK': 9,
    'BUSINESS': 10,
    'COMEDY': 11,
    'SPORTS': 12,
    'BLACK VOICES': 13,
    'HOME & LIVING': 14,
    'PARENTS': 15,
    'THE WORLDPOST': 16,
    'WEDDINGS': 17,
    'WOMEN': 18,
    'CRIME': 19,
    'IMPACT': 20,
    'DIVORCE': 21,
    'WORLD NEWS': 22,
    'MEDIA': 23,
    'WEIRD NEWS': 24,
    'GREEN': 25,
    'WORLDPOST': 26,
    'RELIGION': 27,
    'STYLE': 28,
    'SCIENCE': 29,
    'TECH': 30,
    'TASTE': 31,
    'MONEY': 32,
    'ARTS': 33,
    'ENVIRONMENT': 34,
    'FIFTY': 35,
    'GOOD NEWS': 36,
    'U.S. NEWS': 37,
    'ARTS & CULTURE': 38,
    'COLLEGE': 39,
    'LATINO VOICES': 40,
    'CULTURE & ARTS': 41,
    'EDUCATION': 42
}

# %%
df_balanced['classifier']=df_balanced['category'].map(category_dict)

# %%
df_balanced.head()
# Out:
#                                                     link  \
# 81347  https://www.huffingtonpost.com/entry/huffpost-...
# 12402  https://www.huffingtonpost.com/entry/cambridge...
# 86846  https://www.huffingtonpost.com/entry/oregon-gu...
# 42243  https://www.huffingtonpost.com/entry/trump-ind...
# 74491  https://www.huffingtonpost.comhttp://www.msnbc...
#
#                                                 headline  category  \
# 81347  HuffPost Rise: What You Need To Know On Decemb...  POLITICS
# 12402  Cambridge Analytica Execs Bragged Of Using Fak...  POLITICS
# 86846  Even Americans Who Favor Gun Control Aren't Ve...  POLITICS
# 42243  Indiana Workers Beg Governor To Save Their Job...  POLITICS
# 74491  Report: Bernie Didn't Have A Concession Speech...  POLITICS
#
#                                        short_description             authors  \
# 81347  Welcome to the HuffPost Rise Morning Newsbrief...
# 12402  The admissions were recorded during a probe in...      Nina Golgowski
# ...

# %%
df_balanced.reset_index()
# Out:
#         index                                               link  \
# 0       81347  https://www.huffingtonpost.com/entry/huffpost-...
# 1       12402  https://www.huffingtonpost.com/entry/cambridge...
# 2       86846  https://www.huffingtonpost.com/entry/oregon-gu...
# 3       42243  https://www.huffingtonpost.com/entry/trump-ind...
# 4       74491  https://www.huffingtonpost.comhttp://www.msnbc...
# ...       ...                                                ...
# 34471  168440  https://www.huffingtonpost.com/entry/the-hoax_...
# 34472  177689  https://www.huffingtonpost.com/entry/extreme-w...
# 34473  143926  https://www.huffingtonpost.com/entry/orangutan...
# 34474  165650  https://www.huffingtonpost.com/entry/extremely...
# 34475  146497  https://www.huffingtonpost.com/entry/sustainab...
#
#                                                 headline     category  \
# 0      HuffPost Rise: What You Need To Know On Decemb...     POLITICS
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(df_balanced['processed_headline'],df_balanced['classifier'],test_size=0.2,random_state=2025,stratify=df_balanced['classifier'])

# %%
X_train.shape
# Out:
# (27580,)

# %%
Y_train.shape
# Out:
# (27580,)

# %%
X_test.shape
# Out:
# (6896,)

# %%
Y_test.shape
# Out:
# (6896,)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB
clf=Pipeline([('vectorizer',CountVectorizer()),('nb',MultinomialNB())])

# %%
clf.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('vectorizer', CountVectorizer()), ('nb', MultinomialNB())])

# %%
Y_pred=clf.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.37      0.40      0.39       203
#            2       0.39      0.33      0.36       203
#            3       0.31      0.29      0.30       202
#            4       0.54      0.46      0.50       203
#            5       0.49      0.63      0.55       203
#            6       0.37      0.31      0.33       203
#            7       0.27      0.23      0.25       202
#            8       0.51      0.54      0.53       202
#            9       0.51      0.46      0.48       203
#           10       0.41      0.33      0.36       203
#           11       0.50      0.53      0.52       203
#           12       0.51      0.59      0.55       203
#           13       0.43      0.36      0.39       203
#           14       0.52      0.67      0.59       203
#           15       0.34      0.42      0.37       203
#           16       0.41      0.48      0.44       203
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB
clf=Pipeline([('vectorizer',CountVectorizer(ngram_range=(1,42))),('nb',MultinomialNB())])
clf.fit(X_train,Y_train)
Y_pred=clf.predict(X_test)
from sklearn.metrics import classification_report
print(classification_report(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.38      0.43      0.40       203
#            2       0.40      0.30      0.34       203
#            3       0.32      0.34      0.33       202
#            4       0.56      0.45      0.50       203
#            5       0.48      0.65      0.55       203
#            6       0.41      0.32      0.36       203
#            7       0.27      0.22      0.24       202
#            8       0.54      0.58      0.56       202
#            9       0.51      0.44      0.47       203
#           10       0.41      0.32      0.36       203
#           11       0.49      0.53      0.51       203
#           12       0.53      0.66      0.59       203
#           13       0.45      0.42      0.44       203
#           14       0.54      0.68      0.60       203
#           15       0.34      0.40      0.37       203
#           16       0.42      0.49      0.45       203
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB
clf=Pipeline([('vectorizer',TfidfVectorizer(ngram_range=(1,2))),('nb',MultinomialNB())])
clf.fit(X_train,Y_train)
Y_pred=clf.predict(X_test)
from sklearn.metrics import classification_report
print(classification_report(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.41      0.44      0.43       203
#            2       0.36      0.30      0.33       203
#            3       0.35      0.32      0.34       202
#            4       0.55      0.50      0.52       203
#            5       0.51      0.63      0.56       203
#            6       0.37      0.32      0.34       203
#            7       0.24      0.23      0.23       202
#            8       0.62      0.60      0.61       202
#            9       0.51      0.47      0.49       203
#           10       0.42      0.31      0.36       203
#           11       0.54      0.52      0.53       203
#           12       0.56      0.64      0.59       203
#           13       0.48      0.38      0.43       203
#           14       0.52      0.69      0.60       203
#           15       0.33      0.45      0.38       203
#           16       0.42      0.47      0.44       203
# ...

# %%
df_balanced.replace(r'^\s*$', np.nan, regex=True, inplace=True)

# %%
df_balanced.isnull().sum()
# Out:
# link                     0
# headline                 1
# category                 0
# short_description     4026
# authors               6758
# date                     0
# processed_headline      21
# classifier               0
# dtype: int64

# %%
df_balanced.dropna(inplace=True)

# %%
df_balanced.isnull().sum()
# Out:
# link                  0
# headline              0
# category              0
# short_description     0
# authors               0
# date                  0
# processed_headline    0
# classifier            0
# dtype: int64

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB
clf=Pipeline([('vectorizer',TfidfVectorizer(ngram_range=(1,2))),('nb',MultinomialNB())])
clf.fit(X_train,Y_train)
Y_pred=clf.predict(X_test)
from sklearn.metrics import classification_report
print(classification_report(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.41      0.44      0.43       203
#            2       0.36      0.30      0.33       203
#            3       0.35      0.32      0.34       202
#            4       0.55      0.50      0.52       203
#            5       0.51      0.63      0.56       203
#            6       0.37      0.32      0.34       203
#            7       0.24      0.23      0.23       202
#            8       0.62      0.60      0.61       202
#            9       0.51      0.47      0.49       203
#           10       0.42      0.31      0.36       203
#           11       0.54      0.52      0.53       203
#           12       0.56      0.64      0.59       203
#           13       0.48      0.38      0.43       203
#           14       0.52      0.69      0.60       203
#           15       0.33      0.45      0.38       203
#           16       0.42      0.47      0.44       203
# ...

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

clf = Pipeline([
    ('vectorizer', TfidfVectorizer(ngram_range=(1, 2))),
    ('clf', LogisticRegression(max_iter=1000, class_weight='balanced'))
])

clf.fit(X_train, Y_train)
Y_pred = clf.predict(X_test)
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.37      0.46      0.41       203
#            2       0.33      0.33      0.33       203
#            3       0.31      0.31      0.31       202
#            4       0.48      0.48      0.48       203
#            5       0.47      0.60      0.53       203
#            6       0.32      0.31      0.32       203
#            7       0.24      0.28      0.25       202
#            8       0.68      0.56      0.62       202
#            9       0.51      0.40      0.45       203
#           10       0.38      0.32      0.35       203
#           11       0.52      0.51      0.51       203
#           12       0.52      0.61      0.56       203
#           13       0.47      0.33      0.38       203
#           14       0.53      0.60      0.56       203
#           15       0.30      0.36      0.32       203
#           16       0.44      0.40      0.42       203
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB
clf=Pipeline([('vectorizer',TfidfVectorizer(ngram_range=(1,2))),('nb',MultinomialNB())])
clf.fit(X_train,Y_train)
Y_pred=clf.predict(X_test)
from sklearn.metrics import classification_report
print(classification_report(Y_test,Y_pred))
